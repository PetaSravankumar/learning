# %%
import pandas as pd
l=[10,20,30,40,50]
index=['a','b','c','d','e']
a=pd.Series(l,index)
print(a)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
print(a[3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(a[c])
#
# NameError: name 'c' is not defined
