# %%
import pandas as pd
import numpy as np
l=[10,20,30,40]
a=pd.Series(l)
print(a)
print(type(a))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
a=np.array(l)
b=pd.Series(a)
print(b)
print(type(a))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# <class 'numpy.ndarray'>
