# %%
import pandas as pd
import numpy as np
l=[10,20,30,40]
a=pd.Series(l)
print(a)
print(type(a))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
a=np.array(l)
b=pd.Series(a)
print(b)
print(type(a))
print(type(b))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# <class 'numpy.ndarray'>
# <class 'pandas.core.series.Series'>

# %%
import numpy as np
import pandas as pd
l=[10,20,30,40,50]
a=pd.Series(l)
print(a)
print(a[1])
print(a[3])
print(a.iloc[-2])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# 20
# 40
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\SRAVAN\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: -2 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 8
#       6 print(a[1])
#       7 print(a[3])
# ----> 8 print(a[-2])
#
# File c:\Users\SRAVAN\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# ...
