# %%
l=[10,20,30,40,50]
l1=l
l2=l[1:4]

# %%
print(l)
print(l1)
print(l2)
print(id(l))
print(id(l1))
print(id(l2))
# Out:
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]
# [20, 30, 40]
# 1174787863360
# 1174787863360
# 1174787864384

# %%
l[2]=300
print(l)
print(l1)
print(l2)
print(id(l))
print(id(l1))
print(id(l2))
print(l2)
# Out:
# [10, 20, 300, 40, 50]
# [10, 20, 300, 40, 50]
# [20, 30, 40]
# 1174787863360
# 1174787863360
# 1174787864384
# [20, 30, 40]

# %%
import numpy as np
l=[[1,2],[3,4]]
a=np.array(l)
res=np.linalg.det(a)
print(res)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 l=[[1,2],[3,4]]
# ----> 3 a=np.array()
#       4 res=np.linalg.det(a)
#       5 print(res)
#
# TypeError: array() missing required argument 'object' (pos 0)
