# %%
l=[10,20,30,40,50]
l1=l
l2=l[1:4]

# %%
print(l)
print(l1)
print(l2)
print(id(l))
print(id(l1))
print(id(l2))
# Out:
# [10, 20, 300, 40, 50]
# [10, 20, 300, 40, 50]
# [20, 30, 40]
# 2200632680576
# 2200632680576
# 2200632854144

# %%
l[2]=300
print(l)
print(l1)
print(l2)
print(id(l))
print(id(l1))
print(id(l2))
# Out:
# [10, 20, 300, 40, 50]
# [10, 20, 300, 40, 50]
# [20, 30, 40]
# 2200632680576
# 2200632680576
# 2200632854144
