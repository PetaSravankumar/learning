# %%
import numpy as np
l=[[1,7,5],[18,143,420],[69,96,999]]
a=np.array(l)
print(a)
# Out:
# [[  1   7   5]
#  [ 18 143 420]
#  [ 69  96 999]]

# %%
print(a.min())
# Out:
# 1

# %%
print(a.max())
# Out:
# 999

# %%
print(a.sum())
