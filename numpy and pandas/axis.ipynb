# %%
import numpy as np
l=[[1,7,5],[18,143,420],[69,96,999]]
a=np.array(l)
print(a)
# Out:
# [[  1   7   5]
#  [ 18 143 420]
#  [ 69  96 999]]

# %%
print(a.min())
# Out:
# 1

# %%
print(a.max())
# Out:
# 999

# %%
print(a.sum())
# Out:
# 1758

# %%
print(a.mean())
# Out:
# 195.33333333333334

# %%
print(a.std(
    
))
# Out:
# 310.16662188787063

# %%
print(a.min(axis=0))
print(a.min(axis=1))
# Out:
# [1 7 5]
# [ 1 18 69]

# %%
print(a.max(axis=0))
print(a.max(axis=1))
# Out:
# [ 69 143 999]
# [  7 420 999]

# %%
l=[10,20,30,40]
a=np.array(l)
print(a)
print(a.flags)
# Out:
# [10 20 30 40]
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : True
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False

# %%
a[1]=200
print(a)
# Out:
# [ 10 200  30  40]

# %%
a.flags['WRITEABLE']=False
print(a.flags)
a[2]=300
print(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 a.flags['WRITEABLE']=False
# ----> 3 a[2]=300
#       4 print(a)
#       5 print(a.flags)
#
# ValueError: assignment destination is read-only
