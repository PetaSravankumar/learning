# %%
import numpy as np
l=[[1,7,5],[18,143,420],[69,96,999]]
a=np.array(l)
print(a)
# Out:
# [[  1   7   5]
#  [ 18 143 420]
#  [ 69  96 999]]

# %%
print(a.min())
# Out:
# 1

# %%
print(a.max())
# Out:
# 999

# %%
print(a.sum())
# Out:
# 1758

# %%
print(a.mean())
# Out:
# 195.33333333333334

# %%
print(a.std(
    
))
# Out:
# 310.16662188787063

# %%
print(a.min(axis=0))
print(a.min(axis=1))
# Out:
# [1 7 5]
